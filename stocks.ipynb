# %%
import load_stocks as stocks

# %%
stocks.set_stocks().head()
# Out:
#                  AAPL         SPY        GOOG        TSM       NVDA  \
# 2016-08-17  27.305000  218.369995  779.909973  28.980000  61.150002
# 2016-08-18  27.270000  218.860001  777.500000  29.160000  62.099998
# 2016-08-19  27.340000  218.539993  775.419983  28.639999  62.259998
# 2016-08-22  27.127501  218.529999  772.150024  28.400000  62.520000
# 2016-08-23  27.212500  218.970001  772.080017  28.500000  62.910000
#
#                  MSFT       PYPL         VGT        AMZN         IBM  \
# 2016-08-17  57.560001  38.139999  117.250000  764.630005  160.440002
# 2016-08-18  57.599998  38.220001  117.440002  764.460022  161.360001
# 2016-08-19  57.619999  38.090000  117.699997  757.309998  160.039993
# 2016-08-22  57.669998  38.110001  117.650002  759.479980  160.000000
# 2016-08-23  57.889999  37.860001  118.199997  762.450012  160.259995
#
#                  NFLX    HPQ       SONY       DELL
# 2016-08-17  96.370003  14.50  32.369999  23.809525
# ...

# %%
stocks.get_stocks_list()
# Out:
# ['AAPL',
#  'SPY',
#  'GOOG',
#  'TSM',
#  'NVDA',
#  'MSFT',
#  'PYPL',
#  'VGT',
#  'AMZN',
#  'IBM',
#  'NFLX',
#  'HPQ',
#  'SONY',
#  'DELL']

# %%
stocks.set_lags().head()
# Out:
#                  AAPL   AAPL Lag     SPY Lag    GOOG Lag    TSM Lag  \
# 2016-08-18  27.270000  27.305000  218.369995  779.909973  28.980000
# 2016-08-19  27.340000  27.270000  218.860001  777.500000  29.160000
# 2016-08-22  27.127501  27.340000  218.539993  775.419983  28.639999
# 2016-08-23  27.212500  27.127501  218.529999  772.150024  28.400000
# 2016-08-24  27.007500  27.212500  218.970001  772.080017  28.500000
#
#              NVDA Lag   MSFT Lag   PYPL Lag     VGT Lag    AMZN Lag  \
# 2016-08-18  61.150002  57.560001  38.139999  117.250000  764.630005
# 2016-08-19  62.099998  57.599998  38.220001  117.440002  764.460022
# 2016-08-22  62.259998  57.619999  38.090000  117.699997  757.309998
# 2016-08-23  62.520000  57.669998  38.110001  117.650002  759.479980
# 2016-08-24  62.910000  57.889999  37.860001  118.199997  762.450012
#
#                IBM Lag   NFLX Lag  HPQ Lag   SONY Lag   DELL Lag
# 2016-08-18  160.440002  96.370003    14.50  32.369999  23.809525
# ...

# %%
#apple earnings
stocks.apple_earning.head()
# Out:
#            Quarter End  Estimated EPS  Actual EPS  Result
# Date
# 2015-01-27  2014-12-31           0.65        0.77    1.18
# 2015-04-27  2015-03-31           0.55        0.58    1.05
# 2015-07-21  2015-06-30           0.45        0.46    1.02
# 2015-10-27  2015-09-30           0.47        0.49    1.04
# 2016-01-26  2015-12-31           0.81        0.82    1.01

# %%
#iphone launch
stocks.iphone_launch.head()
# Out:
#             iphone
# Date
# 2007-06-29       1
# 2008-07-11       1
# 2010-06-24       1
# 2012-09-21       1
# 2014-09-19       1

# %%
stocks.combine_lags_appleInfo().head()
#         ...,
#         [0.44131112, 0.45543223, 0.44631635, 0.44346231, 0.44640635],
#         [0.45543223, 0.44631635, 0.44346231, 0.45176883, 0.45375145],
#         [0.44631635, 0.44346231, 0.45176883, 0.45920216, 0.4492055 ]]),
#  array([[0.44346231, 0.45176883, 0.45920216, 0.45460161, 0.45158371],
#         [0.45176883, 0.45920216, 0.45460161, 0.45700839, 0.45480374],
#         [0.45920216, 0.45460161, 0.45700839, 0.4602671 , 0.45286749],
#         ...,
#         [0.92860638, 0.94181166, 0.947179  , 0.94982003, 0.9611912 ],
#         [0.94181166, 0.947179  , 0.94982003, 0.97273756, 0.97853307],
#         [0.947179  , 0.94982003, 0.97273756, 0.99028775, 1.        ]]),
#  array([[0.00934442],
#         [0.00801853],
#         [0.00776597],
#         [0.0060402 ],
# ...

# %%
stocks.reshapeFeatures_stocks()
# Out:
# (array([[[0.0126728 ],
#          [0.01326916],
#          [0.01145876],
#          [0.01218292],
#          [0.01031254]],
#
#         [[0.01326916],
#          [0.01145876],
#          [0.01218292],
#          [0.01043642],
#          [0.00934442]],
#
#         [[0.01145876],
#          [0.01218292],
#          [0.01043642],
#          [0.00945667],
#          [0.00801853]],
#
#         ...,
#
#         [[0.44131112],
#          [0.45543223],
#          [0.44631635],
#          [0.44346231],
#          [0.44640635]],
#
#         [[0.45543223],
#          [0.44631635],
#          [0.44346231],
#          [0.45176883],
#          [0.45375145]],
#
#         [[0.44631635],
#          [0.44346231],
#          [0.45176883],
#          [0.45920216],
#          [0.4492055 ]]]),
#  array([[[0.44346231],
#          [0.45176883],
#          [0.45920216],
#          [0.45460161],
#          [0.45158371]],
#
#         [[0.45176883],
#          [0.45920216],
#          [0.45460161],
# ...

# %%
result = stocks.get_predictions_stocks()
# Out:
# step 1. compile the model
# step 2. model summary
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 5, 5)              140
# _________________________________________________________________
# flatten (Flatten)            (None, 25)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 26
# ...
# Total params: 166
# Trainable params: 166
# Non-trainable params: 0
# _________________________________________________________________
# step 3. Train the model
# Epoch 1/35
# 857/857 [==============================] - 2s 1ms/step - loss: 1.4643e-04
# Epoch 2/35
# 857/857 [==============================] - 1s 1ms/step - loss: 6.9670e-04
# Epoch 3/35
# 857/857 [==============================] - 1s 1ms/step - loss: 3.9071e-04
# Epoch 4/35
# ...

# %%
result.plot(figsize=(18, 10))
# Out:
# <AxesSubplot:>

# %%
result
# Out:
#                   Real   Predicted
# 2020-01-23   79.807503   79.731667
# 2020-01-24   79.577499   80.059738
# 2020-01-27   77.237503   79.896492
# 2020-01-28   79.422501   78.425240
# 2020-01-29   81.084999   79.529587
# ...                ...         ...
# 2021-07-01  137.270004  112.883392
# 2021-07-02  139.960007  113.088615
# 2021-07-06  142.020004  114.139877
# 2021-07-07  144.570007  114.950012
# 2021-07-08  143.240005  115.788040
#
# [368 rows x 2 columns]

# %%
stocks.plot_correlations()
# Out:
# <AxesSubplot:>
